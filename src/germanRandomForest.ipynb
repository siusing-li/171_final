# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, mean_squared_error, accuracy_score, roc_auc_score, roc_curve, auc
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %%
file_list = ['germanAppliance2.csv', 'germanBusiness.csv', 'germanCarNew.csv', 'germanCarUsed.csv',
            'germanEducation2.csv', 'germanFurniture.csv', 'germanOther.csv', 
            'germanRadio_TV.csv', 'germanRepairs.csv', 'germanRetraining2.csv']

# Initialize an empty dictionary to store DataFrames
dataframes = {}

# Loop through the files and read them into DataFrames
for file in file_list:
    df = pd.read_csv(f"../datasets/cleanData/{file}")
    dataframes[file[:-4]] = df

for name, df in dataframes.items():
    print(name)
    train, test = train_test_split(df, test_size=0.20, random_state=12)
    # The remaining
    X_train, y_train = train.drop(columns=['Class']) ,train['Class']
    X_test, y_test = test.drop(columns=['Class']), test['Class']

    # Feature scaling
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test= sc.transform(X_test)

    # Define the hyperparameters and values to tune
    param_grid = {
        'n_estimators': [50, 100, 150, 300],
        'max_depth': [None],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 3],
        'criterion': ['gini']
    }

    # Initialize the Random Forest model
    rf_cls = RandomForestClassifier(random_state=24)

    # Perform Grid Search Cross-Validation
    grid_search = GridSearchCV(estimator=rf_cls, param_grid=param_grid, scoring='accuracy', cv=3)
    grid_search.fit(X_train, y_train)

    # Get the best parameters
    best_params = grid_search.best_params_
    print("Best Parameters:", best_params)

    # Fit the classifier with the best parameters
    # Get the best model from the grid search
    best_rf_cls = grid_search.best_estimator_

    # Make predictions on the test set using the best model
    y_pred = best_rf_cls.predict(X_test)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    report = classification_report(y_test, y_pred)

    print("Accuracy:", accuracy)
    print("MSE:", mse)
    print("Classification Report:\n", report)


    # Predict probabilities on the test set
    y_prob = best_rf_cls.predict_proba(X_test)[:, 1]

    # Compute ROC curve and AUC
    fpr, tpr, thresholds = roc_curve(y_test, y_prob, pos_label=1)
    roc_auc =  auc(tpr, fpr)

    # Plot ROC curve
    plt.figure(figsize=(8, 8))
    plt.plot(tpr, fpr, label=f'AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], linestyle='--', color='red', label='Random')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'{name} Receiver Operating Characteristic (ROC) Curve for Random Forest')
    plt.legend()
    plt.show()
# Out:
# germanAppliance2
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50}
# Accuracy: 0.6666666666666666
# MSE: 0.3333333333333333
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      0.50      0.67         2
#            2       0.50      1.00      0.67         1
#
#     accuracy                           0.67         3
#    macro avg       0.75      0.75      0.67         3
# weighted avg       0.83      0.67      0.67         3
# germanBusiness
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
# Accuracy: 0.75
# MSE: 0.25
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.85      0.79      0.81        14
#            2       0.57      0.67      0.62         6
#
#     accuracy                           0.75        20
#    macro avg       0.71      0.73      0.72        20
# weighted avg       0.76      0.75      0.75        20
# germanCarNew
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 50}
# Accuracy: 0.8085106382978723
# MSE: 0.19148936170212766
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.88      0.85      0.87        34
#            2       0.64      0.69      0.67        13
#
#     accuracy                           0.81        47
#    macro avg       0.76      0.77      0.77        47
# weighted avg       0.81      0.81      0.81        47
# germanCarUsed
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Accuracy: 0.9047619047619048
# MSE: 0.09523809523809523
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.95      0.95      0.95        20
#            2       0.00      0.00      0.00         1
#
#     accuracy                           0.90        21
#    macro avg       0.47      0.47      0.48        21
# weighted avg       0.90      0.90      0.90        21
# germanEducation2
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 50}
# Accuracy: 0.5
# MSE: 0.5
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      0.17      0.29         6
#            2       0.44      1.00      0.62         4
#
#     accuracy                           0.50        10
#    macro avg       0.72      0.58      0.45        10
# weighted avg       0.78      0.50      0.42        10
# germanFurniture
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# Accuracy: 0.7027027027027027
# MSE: 0.2972972972972973
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.71      0.96      0.81        25
#            2       0.67      0.17      0.27        12
#
#     accuracy                           0.70        37
#    macro avg       0.69      0.56      0.54        37
# weighted avg       0.69      0.70      0.64        37
# germanOther
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# Accuracy: 0.3333333333333333
# MSE: 0.6666666666666666
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.50      0.50      0.50         2
#            2       0.00      0.00      0.00         1
#
#     accuracy                           0.33         3
#    macro avg       0.25      0.25      0.25         3
# weighted avg       0.33      0.33      0.33         3
# germanRadio_TV
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 150}
# Accuracy: 0.7678571428571429
# MSE: 0.23214285714285715
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.79      0.95      0.86        43
#            2       0.50      0.15      0.24        13
#
#     accuracy                           0.77        56
#    macro avg       0.64      0.55      0.55        56
# weighted avg       0.72      0.77      0.72        56
# germanRepairs
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# Accuracy: 0.4
# MSE: 0.6
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.50      0.33      0.40         3
#            2       0.33      0.50      0.40         2
#
#     accuracy                           0.40         5
#    macro avg       0.42      0.42      0.40         5
# weighted avg       0.43      0.40      0.40         5
# germanRetraining2
# c:\Users\abdul\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   warnings.warn(
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# Accuracy: 1.0
# MSE: 0.0
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\abdul\anaconda3\lib\site-packages\sklearn\metrics\_ranking.py:990: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
